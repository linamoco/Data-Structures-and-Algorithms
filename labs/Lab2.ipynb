# %% [markdown]
# # Лабораторная работа №2
# ## Выполнила студентка группы БВТ 2005 Бражникова Ангелина Владимировна

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)

# %% [markdown]
# ### Задание №1
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию начального набора случайных данных. Для всех вариантов добавить реализацию добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма поиска и сравнить его со временем работы стандартной функции поиска, используемой в выбранном языке программирования.

# %%
import time
import pandas as pd
from random import randint

def random_list(min_value, max_value, n):
    return [randint(min_value,max_value) for i in range(n)]

massiv = random_list(0, 100, 10)
sorted_massiv = sorted(massiv)

# %%
#Бинарный поиск
start_time = time.time()
#TODO
def binary_search_index(array, key):
    n = len(array)
    left, right = 0, n - 1
    middle = (left + right) // 2
    while right - left > 1:
        if key <= array[middle]:   
            right = middle     
        else:
            left = middle                 
        middle = (left + right) // 2      
    return right

def binary_search_find(array, key):
    k = binary_search_index(array, key)
    assert key == array[k], "Искомый элемент не найден"
    return k
time_1 = round((time.time() - start_time)*1000)

# Вставка
def binary_search_insert(array, key):
    array.insert(binary_search_index(array, key), key)
    return array

# Удаление
def binary_search_remove(array, key):
    element = binary_search_find(array, key)
    array.pop(element)
    return array


print('Исходный массив')
print(massiv)

print('Отсортированный массив')
print(sorted_massiv)

print('Вставка элемента 71 в массив')

print(binary_search_insert(sorted_massiv, 71))

print('Поиск элемента 71 в массиве')
print(binary_search_find(sorted_massiv, 71))

print('Удаление элемента 71 из массива')
print(binary_search_remove(sorted_massiv, 71))

print('Время работы поиска элемента')
print("--- {0} ms ---".format(time_1))
# Out:
# Исходный массив
# [40, 49, 85, 97, 72, 27, 32, 57, 99, 71]
# Отсортированный массив
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Вставка элемента 71 в массив
# [27, 32, 40, 49, 57, 71, 71, 72, 85, 97, 99]
# Поиск элемента 71 в массиве
# 5
# Удаление элемента 71 из массива
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Время работы поиска элемента
# --- 0 ms ---

# %%
#Бинарное дерево

class node:
    def __init__(self,value=None):
        self.value=value
        self.left_child=None
        self.right_child=None
        self.parent=None 

class binary_search_tree:
    def __init__(self):
        self.root=None


        def insert(self,value):
        if self.root==None:
            self.root=node(value)
        else:
            self._insert(value,self.root)

    def _insert(self,value,cur_node):
        if value<cur_node.value:
            if cur_node.left_child==None:
                cur_node.left_child=node(value)
                cur_node.left_child.parent=cur_node # set parent
            else:
                self._insert(value,cur_node.left_child)
        elif value>cur_node.value:
            if cur_node.right_child==None:
                cur_node.right_child=node(value)
                cur_node.right_child.parent=cur_node # set parent
            else:
                self._insert(value,cur_node.right_child)
        else:
            print("Value already in tree!")

    def print_tree(self):
        if self.root!=None:
            self._print_tree(self.root)

    def _print_tree(self,cur_node):
        if cur_node!=None:
            self._print_tree(cur_node.left_child)
            print (str(cur_node.value))
            self._print_tree(cur_node.right_child)

    def height(self):
        if self.root!=None:
            return self._height(self.root,0)
        else:
            return 0

    def _height(self,cur_node,cur_height):
        if cur_node==None: return cur_height
        left_height=self._height(cur_node.left_child,cur_height+1)
        right_height=self._height(cur_node.right_child,cur_height+1)
        return max(left_height,right_height)

    def find(self,value):
        if self.root!=None:
            return self._find(value,self.root)
        else:
            return None

    def _find(self,value,cur_node):
        if value==cur_node.value:
            return cur_node
        elif value<cur_node.value and cur_node.left_child!=None:
            return self._find(value,cur_node.left_child)
        elif value>cur_node.value and cur_node.right_child!=None:
            return self._find(value,cur_node.right_child)


    def delete_value(self,value):
        return self.delete_node(self.find(value))

    def delete_node(self,node):
        if node==None or self.find(node.value)==None:
            print("Node to be deleted not found in the tree!")
            return None 
        def min_value_node(n):
            current=n
            while current.left_child!=None:
                current=current.left_child
            return current
        def num_children(n):
            num_children=0
            if n.left_child!=None: num_children+=1
            if n.right_child!=None: num_children+=1
            return num_children
        node_parent=node.parent
        node_children=num_children(node)
        if node_children==0:
            if node_parent!=None:
                if node_parent.left_child==node:
                    node_parent.left_child=None
                else:
                    node_parent.right_child=None
            else:
                self.root=None
        if node_children==1:
            if node.left_child!=None:
                child=node.left_child
            else:
                child=node.right_child
            if node_parent!=None:
                if node_parent.left_child==node:
                    node_parent.left_child=child
                else:
                    node_parent.right_child=child
            else:
                self.root=child
            child.parent=node_parent
        if node_children==2:
            successor=min_value_node(node.right_child)
            node.value=successor.value
            self.delete_node(successor)

            
    start_time = time.time()
    def search(self,value):
        if self.root!=None:
            return self._search(value,self.root)
        else:
            return False

    def _search(self,value,cur_node):
        if value==cur_node.value:
            return True
        elif value<cur_node.value and cur_node.left_child!=None:
            return self._search(value,cur_node.left_child)
        elif value>cur_node.value and cur_node.right_child!=None:
            return self._search(value,cur_node.right_child)
        return False 
    
time_2 = round((time.time() - start_time)*1000)
def fill_tree(tree, num_elems=10, max_int=100):
    from random import randint
    for _ in range(num_elems):
        cur_elem = randint(0, max_int)
        tree.insert(cur_elem)
    return tree

tree = binary_search_tree()
tree = fill_tree(tree)

print ("Исходное дерево")
tree.print_tree()
print("Поиск значений 17 и 71")

print (tree.search(17))
print (tree.search(71))

print ("Вставка элемента 71 в массив")
tree.insert(71)
tree.print_tree()
print ("Поиск значений 17 и 71 после вставки")
print (tree.search(17))
print (tree.search(71))
print ("Удаление элемента 71")
tree.delete_value(71)
tree.print_tree()
print ("Результат после удаления")
print (tree.search(17))
print (tree.search(71))

print('Время работы поиска элемента')
print("--- {0} ms ---".format(time_2))
# Out:
# Value already in tree!
# Исходное дерево
# 25
# 28
# 33
# 38
# 53
# 59
# 60
# 90
# 100
# Поиск значений 17 и 71
# False
# False
# Вставка элемента 71 в массив
# 25
# 28
# 33
# 38
# 53
# 59
# 60
# 71
# 90
# 100
# Поиск значений 17 и 71 после вставки
# False
# True
# Удаление элемента 71
# 25
# 28
# 33
# 38
# 53
# 59
# 60
# 90
# 100
# Результат после удаления
# False
# False
# Время работы поиска элемента
# --- 2794 ms ---

# %%
#Метод Фибоначчи 
class FibonacciSearch:
    def __init__(self):
        self.i = 0
        self.p = 0
        self.q = 0
        self.stop = False

    def get_fibonacci_number(self, k):
        first_number = 0
        second_number = 1
        n = 0
        while n < k:
            temp_number = second_number
            second_number = first_number + second_number
            first_number = temp_number
            n = n + 1
        return first_number

    def start_init(self, sequince):
        self.stop = False
        k = 0
        n = len(sequince)
        while (self.get_fibonacci_number(k+1) < len(sequince)):
            k = k+1
        m = self.get_fibonacci_number(k+1)-(n+1)
        self.i = self.get_fibonacci_number(k) - m
        self.p = self.get_fibonacci_number(k-1)
        self.q = self.get_fibonacci_number(k-2)

    def up_index(self):
        if self.p == 1:
            self.stop = True
        self.i = self.i + self.q
        self.p = self.p - self.q
        self.q = self.q - self.p

    def down_index(self):
        if self.q == 0:
            self.stop = True
        self.i = self.i-self.q
        temp = self.q
        self.q = self.p - self.q
        self.p = temp   
        
    start_time = time.time()
    
#ПОИСК
    def search_index(self, sequince, element):
        self.start_init(sequince)
        while not self.stop:
            if self.i < 0:
                self.up_index()
            elif self.i >= len(sequince):
                self.down_index()
            elif sequince[self.i] == element:
                result_index = self.i
                break
            elif element < sequince[self.i]:
                self.down_index()
            elif element > sequince[self.i]:
                self.up_index()
                result_index = self.i +1
        return result_index
    
    def search_find(self, sequince, element):
        k = self.search_index(sequince, element)
        assert element == sequince[k], "Искомый элемент не найден!"
        return k    

    time_3 = round((time.time() - start_time)*1000)
    
#ВСТАВКА
    def insert(self, sequince, element):
        sequince.insert(self.search_index(sequince, element), element)
        return sequince             
    
#УДАЛЕНИЕ
    def remove(self, sequince, element):
        el = self.search_find(sequince, element)
        sequince.pop(el)
        return sequince  
FS = FibonacciSearch()
print('Исходный массив')
print(massiv)

print('Отсортированный массив')
print(sorted_massiv)

print('Вставка элемента 41 в массив')
print(FS.insert(sorted_massiv, 41))

print('Поиск элемента 41 в массиве')
print(FS.search_find(sorted_massiv, 41))

print('Удаление элемента 41 из массива')
print(FS.remove(sorted_massiv, 41))

print('Время работы поиска элемента')
print("--- {0} ms ---".format(FS.time_3))
# Out:
# Исходный массив
# [40, 49, 85, 97, 72, 27, 32, 57, 99, 71]
# Отсортированный массив
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Вставка элемента 41 в массив
# [27, 32, 40, 41, 49, 57, 71, 72, 85, 97, 99]
# Поиск элемента 41 в массиве
# 3
# Удаление элемента 41 из массива
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Время работы поиска элемента
# --- 0 ms ---

# %%
#Интерполяционный   
start_time = time.time()

def interpolation_search_index(lys, val):   
    low = 0                              
    high = (len(lys) - 1)                
    while low <= high and val >= lys[low] and val <= lys[high]:         
        index = low + int(((float(high - low) / ( lys[high] - lys[low])) * ( val - lys[low])))   
        if lys[index] == val:   
            return index
        if lys[index] < val:   
            low = index + 1;
            guess = low
        else:
            high = index - 1;
            guess = high+1
    return guess

def interpolation_search_find(lst, search_item):
    k = interpolation_search_index(lst, search_item)
    assert search_item == lst[k], "Искомый элемент не найден"
    return k

time_4 = round((time.time() - start_time)*1000)

def interpolation_search_insert(lst, search_item):
    lst.insert(interpolation_search_index(lst, search_item), search_item)
    return lst

def interpolation_search_remove(lst, search_item):
    element = interpolation_search_find(lst, search_item)
    lst.pop(element)
    return lst

print('Исходный массив')
print(massiv)

print('Отсортированный массив')
print(sorted_massiv)

print('Вставка элемента 71 в массив')
print(interpolation_search_insert(sorted_massiv, 71))

print('Поиск элемента 71 в массиве')
print(interpolation_search_find(sorted_massiv, 71))

print('Удаление элемента 71 из массива')
print(interpolation_search_remove(sorted_massiv, 71))

print('Время работы поиска элемента')
print("--- {0} ms ---".format(time_4))
# Out:
# Исходный массив
# [40, 49, 85, 97, 72, 27, 32, 57, 99, 71]
# Отсортированный массив
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Вставка элемента 71 в массив
# [27, 32, 40, 49, 57, 71, 71, 72, 85, 97, 99]
# Поиск элемента 71 в массиве
# 6
# Удаление элемента 71 из массива
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Время работы поиска элемента
# --- 0 ms ---

# %%
#стандартная функция поиска
print('Исходный массив')
print(massiv)

print('Отсортированный массив')
print(sorted_massiv)

start_time = time.time()

print('Cтандартная функция поиска 71')
print(71 in sorted_massiv)

time_5 = round((time.time() - start_time)*1000)

print('Время работы поиска элемента')
print("--- {0} ms ---".format(time_5))
# Out:
# Исходный массив
# [40, 49, 85, 97, 72, 27, 32, 57, 99, 71]
# Отсортированный массив
# [27, 32, 40, 49, 57, 71, 72, 85, 97, 99]
# Cтандартная функция поиска 71
# True
# Время работы поиска элемента
# --- 0 ms ---

# %%
table_search = [["Бинарный поиск", time_1],
                ["Поиск в бинарном дереве", time_2], 
                ["Поиск методом Фибоначчи", FS.time_3], 
                ["Интерполяционный поиск", time_4],
                ["Cтандартная функция поиска", time_5]]

pd.DataFrame(table_search, columns=["Алгортим","Время работы алгоритма"])
# Out:
#                      Алгортим  Время работы алгоритма
# 0              Бинарный поиск                       0
# 1     Поиск в бинарном дереве                    2794
# 2     Поиск методом Фибоначчи                       0
# 3      Интерполяционный поиск                       0
# 4  Cтандартная функция поиска                       0

# %% [markdown]
# ### Задание №2
# Написать соответствующие решения для заданных методов.

# %%
#Простое рехэширование
hashTable =[[None],]*11

def checkPrime(n):          
    if n == 1 or n == 0:
        return 0
    
    for i in range(2, n//2): 
        if n % i == 0:
            return 0
    return 1

def getPrime(n):          
    if n % 2 == 0:
        n = n + 1
    while not checkPrime(n):
        n += 2
    return n

def hashFunction(key):    
    capacity = getPrime(11)
    return key % capacity 

def insertData(key, data):  
    index = hashFunction(key)     
    if hashTable[index] == [None]:     
        hashTable[index] = [key, data]
    else: 
        while hashTable[index] != [None]:  
            p = index % len(hashTable)
            index = (p + 1)%len(hashTable)
        hashTable[index] = [key, data]       
    
def removeData(key):        
    index = hashFunction(key)
    hashTable[index] = [None]
    
insertData(0, "mango")
insertData(1, "apple")
insertData(6, "meat")
insertData(6, "water")
insertData(6, "ham")
insertData(10, "egg")
insertData(10, "tea")

print("Исходная хеш таблица")
print(hashTable)
removeData(1)
print("Хеш таблица после удаления элемента")
print(hashTable)
# Out:
# Исходная хеш таблица
# [[0, 'mango'], [1, 'apple'], [10, 'tea'], [None], [None], [None], [6, 'meat'], [6, 'water'], [6, 'ham'], [None], [10, 'egg']]
# Хеш таблица после удаления элемента
# [[0, 'mango'], [None], [10, 'tea'], [None], [None], [None], [6, 'meat'], [6, 'water'], [6, 'ham'], [None], [10, 'egg']]

# %%
#Рехэширование с помощью псевдослучайных чисел
hashTable =[[None],]*11

def checkPrime(n):
    if n == 1 or n == 0:
        return 0
    
    for i in range(2, n//2):
        if n % i == 0:
            return 0
    return 1

def getPrime(n):
    if n % 2 == 0:
        n = n + 1
    while not checkPrime(n):
        n += 2
    return n

def hashFunction(key):
    capacity = getPrime(11)
    return key % capacity

def insertData(key, data):
    index = hashFunction(key)
    if hashTable[index] == [None]:
        hashTable[index] = [key, data]
    else:
        while hashTable[index] != [None]:
            index = (index + randint(0,1000)) % len(hashTable)
        hashTable[index] = [key, data] 
        
def removeData(key):
    index = hashFunction(key)
    hashTable[index] = [None]
    
insertData(0, "mango")
insertData(1, "apple")
insertData(6, "meat")
insertData(6, "water")
insertData(6, "ham")
insertData(10, "egg")
insertData(10, "tea")

print("Исходная хеш таблица")
print(hashTable)
removeData(0)
print("Хеш таблица после удаления элемента")
print(hashTable)
# Out:
# Исходная хеш таблица
# [[0, 'mango'], [1, 'apple'], [None], [6, 'ham'], [None], [10, 'tea'], [6, 'meat'], [None], [6, 'water'], [None], [10, 'egg']]
# Хеш таблица после удаления элемента
# [[None], [1, 'apple'], [None], [6, 'ham'], [None], [10, 'tea'], [6, 'meat'], [None], [6, 'water'], [None], [10, 'egg']]

# %%
# Метод цепочек
class ListNode:
    def __init__(self, key, val):
        self.pair = (key, val)
        self.next: Union[None, ListNode] = None
            
class ChainedHashTable:

    def __init__(self):
        self.m = 1000;
        self.h: list[Union[None, ListNode]] = [None]*self.m

    def __setitem__(self, key, value):
        index = self._hash(key)

        cur = self.h[index]
        if cur is None:
            self.h[index] = ListNode(key, value)

        else:
            while True:
                if cur.pair[0] == key:
                    cur.pair = (key, value)
                    return

                if cur.next == None: break
                cur = cur.next

            cur.next = ListNode(key, value)

    def __getitem__(self, key):
        index = self._hash(key)
        cur = self.h[index]

        while cur:
            if cur.pair[0] == key:
                return cur.pair[1]
            else:
                cur = cur.next
        raise KeyError(f"No such key: {key}")

    def _hash(self, key) -> int:
        return key % self.m
def test_hashing(hashable) -> None:
    tests_dict: dict[int, str] = dict({
        54: "cat",
        26: "dog",
        44: "lion",
        15: "tiger",
        20: "duck"
    })

    for k, v in tests_dict.items():
        hashable[k] = v

    for k, v in tests_dict.items():
        assert hashable[k] == v
print("Testing chained hash table")
test_hashing(ChainedHashTable())
print("Chained hash table tests passed")
# Out:
# Testing chained hash table
# Chained hash table tests passed

# %% [markdown]
# ### Задание №3
# Расставить на стандартной 64-клеточной шахматной доске 8 ферзей так, чтобы ни один из них не находился под боем другого». Подразумевается, что ферзь бьёт все клетки, расположенные по вертикалям, горизонталям и обеим диагоналям
# Написать программу,  которая находит хотя бы один способ решения задач.

# %%
board = [[0 for i in range(8)] for j in range(8)]
count = 0

def setQueen(i, j):
    for x in range(8):
        board[x][j] += 1
        board[i][x] += 1
        if 0 <= i+j-x < 8:
            board[i+j-x][x] += 1
        if 0 <= i-j+x < 8:
            board[i-j+x][x] += 1
    board[i][j] = -1
    
def removeQueen(i, j):
    for x in range(8):
        board[x][j] -= 1
        board[i][x] -= 1
        if 0 <= i+j-x < 8:
            board[i+j-x][x] -= 1
        if 0 <= i-j+x < 8:
            board[i-j+x][x] -= 1
    board[i][j] = 0
    
def printPosition():
    global count
    count += 1
    abc = 'abcdefgh'
    ans = []
    for i in range(8):
        for j in range(8):
            if board[i][j] == -1:
                ans.append(abc[j]+str(i+1))
    print(', '.join(ans))
    
def solve(i):
    for j in range(8):
        if board[i][j] == 0:
            setQueen(i, j)
            if i == 7:
                printPosition()
            else:
                solve(i+1)
            removeQueen(i, j)
            
print("------------------Варианты расстановок------------------")
solve(0)
print("------------------Найденное количество расстановок------------------")
print(count)
# Out:
# ------------------Варианты расстановок------------------
# a1, e2, h3, f4, c5, g6, b7, d8
# a1, f2, h3, c4, g5, d6, b7, e8
# a1, g2, d3, f4, h5, b6, e7, c8
# a1, g2, e3, h4, b5, d6, f7, c8
# b1, d2, f3, h4, c5, a6, g7, e8
# b1, e2, g3, a4, c5, h6, f7, d8
# b1, e2, g3, d4, a5, h6, f7, c8
# b1, f2, a3, g4, d5, h6, c7, e8
# b1, f2, h3, c4, a5, d6, g7, e8
# b1, g2, c3, f4, h5, e6, a7, d8
# b1, g2, e3, h4, a5, d6, f7, c8
# b1, h2, f3, a4, c5, e6, g7, d8
# c1, a2, g3, e4, h5, b6, d7, f8
# c1, e2, b3, h4, a5, g6, d7, f8
# c1, e2, b3, h4, f5, d6, g7, a8
# c1, e2, g3, a4, d5, b6, h7, f8
# c1, e2, h3, d4, a5, g6, b7, f8
# c1, f2, b3, e4, h5, a6, g7, d8
# c1, f2, b3, g4, a5, d6, h7, e8
# c1, f2, b3, g4, e5, a6, h7, d8
# c1, f2, d3, a4, h5, e6, g7, b8
# c1, f2, d3, b4, h5, e6, g7, a8
# c1, f2, h3, a4, d5, g6, e7, b8
# c1, f2, h3, a4, e5, g6, b7, d8
# c1, f2, h3, b4, d5, a6, g7, e8
# c1, g2, b3, h4, e5, a6, d7, f8
# c1, g2, b3, h4, f5, d6, a7, e8
# c1, h2, d3, g4, a5, f6, b7, e8
# ...
